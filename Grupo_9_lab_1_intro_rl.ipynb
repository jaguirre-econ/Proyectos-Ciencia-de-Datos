# %% [markdown]
# <a href="https://colab.research.google.com/github/jaguirre-econ/Proyectos-Ciencia-de-Datos/blob/main/Grupo_9_lab_1_intro_rl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 1: Introducción al aprendizaje por refuerzos
#
# Curso Aprendizaje por Refuerzos, Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones
#
# FaMAF, 2023

# %% [markdown]
# ## Introducción
#
# En el siguiente notebook se muestra cómo ejecutar agentes de aprendizaje por refuerzos, los cuáles son necesarios para realizar este Lab.

# %% [markdown]
# ### Repaso rápido

# %% [markdown]
# * Recompensa: señal $r$ recibida desde el entorno que recompensa o castiga el agente según su desempeño con respecto al objetivo de la tarea.
#
# * Valor: función $v_\pi (s)$ que establece cuánto el agente espera percibir de recompensa al seguir la política $\pi$ partiendo desde el estado $s$. También se la suele expresar como $Q_\pi(s,a)$, indicando cuánto el agente espera percibir siguiendo la política $\pi$ partiendo desde el estado $s$ y siguiendo la acción $a$.
#
# * Política: función $\pi(s) \to a$ que mapea un estado a una acción. Se suele expresar como probabilidad de elegir la acción $\pi(a \mid s)$. La política $\epsilon$-greedy, en donde $\epsilon$ es la probabilidad de exploración (normalmente menor que la probabilidad de explotación) está dada por $\pi(a \mid s) = 1 - \epsilon$ si $a$ es la mejor acción, caso contrario pasa a estar dada por $\pi(a \mid s) = \epsilon$.
#
# Por otra parte, en la política Softmax, no se busca la acción con máxima probabilidad sino que se computa la probabilidad de cada una mediante la función Softmax y se realiza un sorteo entre ellas pesado por la misma. Así, para cada acción $a$, $$\pi(a \mid s) = \frac{e^{Q(s,a)/\tau}}{\sum_{\widetilde{a} \in A}e^{Q(s,\widetilde{a})/\tau}}$$

# %% [markdown]
# En este notebook vemos dos algoritmos para actualizar la función de valor (y, por lo tanto, la política de selección de acciones):
#
# * Actualización por SARSA (on-policy).
#
# $$Q(s,a) \gets Q(s,a) + \alpha (r + \gamma Q(s',a') - Q(s,a))$$
#
# Algoritmo completo (a modo de referencia):
#
# ![Algoritmo SARSA](https://github.com/DiploDatos/AprendizajePorRefuerzos/blob/master/images/sarsa.png?raw=1)

# %% [markdown]
# * Actualización por Q-Learning (off-policy)
#
# $$Q(s,a) \gets Q(s,a) + \alpha (r + \gamma \arg\max_{a'} Q(s',a') - Q(s,a))$$
#
# Algoritmo completo (a modo de referencia):
#
# ![Algoritmo Q-Learning](https://github.com/DiploDatos/AprendizajePorRefuerzos/blob/master/images/q_learning.png?raw=1)
#
# Fuente de las imágenes: capítulo 6 de [Reinforcement Learning: An Introduction](http://www.incompleteideas.net/book/the-book.html).

# %% [markdown]
# ## Librería a usar: Librería OpenAI Gym
#
# [OpenAI Gym](https://gym.openai.com/) (Brockman et. al., 2016) es una librería de OpenAI que ofrece entornos y una interfaz estándar con la cuál probar nuestros agentes. Su objetivo es proveer benchmarks unificados para ver el desempeño de algoritmos en el entorno y así poder saber con facilidad cómo es su desempeño comparado con los demás. Parte de la siguiente sección está basada en la [documentación oficial de OpenAI](https://gym.openai.com/docs/).

# %% [markdown]
# La interfaz principal de los ambientes de gym es la interfaz Env. La misma posee cinco métodos principales:
#
# * ```reset(self, seed)``` : Reinicia el estado del entorno, a su estado inicial, devolviendo una observación de dicho estado. Opcionalmente, establece la semilla aleatoria del generador de números aleatorios del presente entorno.
#
# * ```step(self, action)``` : "Avanza" un timestep del ambiente. Devuelve: ```observation, reward, terminated, truncated, info```.
#
# * ```render(self)``` : Muestra en pantalla una parte del ambiente.
#
# * ```close(self)``` : Finaliza con la instancia del agente.
#
#
# Por otra parte, cada entorno posee los siguientes tres atributos principales:
#
# * ```action_space``` : El objeto de tipo Space correspondiente al espacio de acciones válidas.
#
# * ```observation_space``` : El objeto de tipo Space correspondiente a todos los rangos posibles de observaciones.
#
# * ```reward_range``` : Tupla que contiene los valores mínimo y máximo de recompensa posible.

# %% [markdown]
# Algunas de las ejecuciones contienen videos. Para poder verlos se necesita previamente instalar la librería ffmpeg; para instalarla desde Linux ejecutar en consola
#
# ```apt-get install ffmpeg```
#
# desde Mac, reemplazar *apt-get* por *brew*
#
# desde Windows, descargarla desde
#
# [https://ffmpeg.org/download.html](https://ffmpeg.org/download.html)
#
# (Nota: las animaciones son a modo ilustrativo, si no se desea instalar la librería se puede directamente eliminar la línea de código donde se llama al método ``env.render(mode='human')``)

# %% [markdown]
# Código básico de importación y funciones de graficación (no modificar)

# %%
# @title Código básico importacion y utilerías (no modificar)

import itertools
from typing import Any, Callable, Tuple

import numpy as np
import matplotlib.pyplot as plt


def plot_reward_per_episode(rewards_ep) -> None:
    legend = []
    if not isinstance(rewards_ep, dict):
      rewards_ep = {'value': rewards_ep}

    for key, reward_ep in rewards_ep.items():
        legend.append(key)
        episode_rewards = np.array(reward_ep)

        # se suaviza la curva de convergencia
        episode_number = np.linspace(
            1, len(episode_rewards) + 1, len(episode_rewards) + 1)
        acumulated_rewards = np.cumsum(episode_rewards)

        reward_per_episode = [
            acumulated_rewards[i] / episode_number[i]
            for i in range(len(acumulated_rewards))
        ]

        plt.plot(reward_per_episode)

    plt.legend(legend)
    plt.title("Recompensa acumulada por episodio")
    plt.show()


def plot_steps_per_episode(timesteps_eps) -> None:
    legend = []
    if not isinstance(timesteps_eps, dict):
      timesteps_ep = {'value': timesteps_eps}

    for key, timesteps_ep in timesteps_eps.items():
      legend.append(key)
      # se muestra la curva de aprendizaje de los pasos por episodio
      episode_steps = np.array(timesteps_ep)
      plt.plot(np.array(range(0, len(episode_steps))), episode_steps)
    plt.legend(legend)
    plt.title("Pasos (timesteps) por episodio")
    plt.show()


def plot_steps_per_episode_smooth(timesteps_eps) -> None:
    legend = []
    if not isinstance(timesteps_eps, dict):
        timesteps_ep = {'value': timesteps_eps}
    for key, timesteps_ep in timesteps_eps.items():
        legend.append(key)

        episode_steps = np.array(timesteps_ep)

        # se suaviza la curva de aprendizaje
        episode_number = np.linspace(
            1, len(episode_steps) + 1, len(episode_steps) + 1)
        acumulated_steps = np.cumsum(episode_steps)

        steps_per_episode = [
            acumulated_steps[i] / episode_number[i] for i in range(
                len(acumulated_steps))
        ]

        plt.plot(steps_per_episode)
    plt.legend(legend)
    plt.title("Pasos (timesteps) acumulados por episodio")
    plt.show()


def draw_value_matrix(q) -> None:
    n_rows = 4
    n_columns = 12
    n_actions = 4

    # se procede con los cálculos previos a la graficación de la matriz de valor
    q_value_matrix = np.empty((n_rows, n_columns))
    for row in range(n_rows):
        for column in range(n_columns):
            state_values = []

            for action in range(n_actions):
                state_values.append(
                    q.get((row * n_columns + column, action), -100))

            maximum_value = max(
                state_values
            )  # determinamos la acción que arroja máximo valor

            q_value_matrix[row, column] = maximum_value

    # el valor del estado objetivo se asigna en -1 (reward recibido al llegar)
    # para que se coloree de forma apropiada
    q_value_matrix[3, 11] = -1

    # se grafica la matriz de valor
    plt.imshow(q_value_matrix, cmap=plt.cm.RdYlGn)
    plt.tight_layout()
    plt.colorbar()

    for row, column in itertools.product(
        range(q_value_matrix.shape[0]), range(q_value_matrix.shape[1])
    ):
        left_action = q.get((row * n_columns + column, 3), -1000)
        down_action = q.get((row * n_columns + column, 2), -1000)
        right_action = q.get((row * n_columns + column, 1), -1000)
        up_action = q.get((row * n_columns + column, 0), -1000)

        arrow_direction = "D"
        best_action = down_action

        if best_action < right_action:
            arrow_direction = "R"
            best_action = right_action
        if best_action < left_action:
            arrow_direction = "L"
            best_action = left_action
        if best_action < up_action:
            arrow_direction = "U"
            best_action = up_action
        if best_action == -1:
            arrow_direction = ""

        # notar que column, row están invertidos en orden en la línea de abajo
        # porque representan a x,y del plot
        plt.text(column, row, arrow_direction, horizontalalignment="center")

    plt.xticks([])
    plt.yticks([])
    plt.show()

    #print("\n Matriz de mejor acción-valor (en números): \n\n", q_value_matrix)

# %% [markdown]
# Ejemplo: agente CartPole

# %%
from IPython.display import clear_output

try:
  import google.colab
  IN_COLAB = True

  # !pip install gymnasium

except:
  IN_COLAB = False

import gymnasium as gym

# no es posible mostrar videos de ejecución del agente desde Colab
if not IN_COLAB:

    env = gym.make('CartPole-v0')
    env.reset()
    env.render()

    for _ in range(500):
        env.render()
        # se ejecuta una acción aleatoria
        obs, reward, terminated, truncated, info = env.step(
           env.action_space.sample())

        done = terminated or truncated
        if done:
            env.reset()
    env.close()
    clear_output()

# %%
# !apt install ffmpeg -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.

# %% [markdown]
# Ejemplo: agente Mountain Car

# %%
if not IN_COLAB:
    env = gym.make('MountainCar-v0')
    obs = env.reset()
    for t in range(500):
        env.render()
        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
    env.close()
    clear_output()

# %% [markdown]
# ## Ejemplo 1: The Cliff.

# %% [markdown]
# ![](https://github.com/GIDISIA/RLDiplodatos/blob/master/images/cliffwalking.png?raw=1)
#
# donde S= starting point, G= goal
#
# (imagen de Sutton y Barto, 2018)

# %% [markdown]
# Descripción del entorno:
#
# Acciones:
#
# * $\uparrow$ - Arriba
# * $\downarrow$ - Abajo
# * $\rightarrow$ - Derecha
# * $\leftarrow$ - Izquierda
#
# Función de recompensa:
#
# * $-1$ en todos los demás estados
# * $-100$ en el acantilado
#
# Nota: caer en el acantilado devuelve al agente al estado inicial en un mismo episodio

# %% [markdown]
# Vemos los bloques básicos de nuestro agente

# %% [markdown]
# Definimos el método de elección de acciones. En este caso el mismo utiliza la política de exploración $\epsilon$-greedy.

# %%
def choose_action_e_greedy(
        state: int,
        actions: range,
        q: dict,
        hyperparameters: dict,
        random_state: np.random.RandomState,
) -> int:
    """
    Elije una acción de acuerdo al aprendizaje realizado previamente
    usando una política de exploración épsilon-greedy
    """
    # ej: para 4 acciones inicializa en [0,0,0,0]
    q_values = [q.get((state, a), 0.0) for a in actions]
    max_q = max(q_values)
    # sorteamos un número: es menor a épsilon?
    if random_state.uniform() < hyperparameters['epsilon']:
        # sí: se selecciona una acción aleatoria
        return random_state.choice(actions)

    count = q_values.count(max_q)

    # hay más de un máximo valor de estado-acción?
    if count > 1:
        # sí: seleccionamos uno de ellos aleatoriamente
        best = [i for i in range(len(actions)) if q_values[i] == max_q]
        i = random_state.choice(best)
    else:
        # no: seleccionamos el máximo valor de estado-acción
        i = q_values.index(max_q)

    return actions[i]

# %%
def choose_action_softmax() -> int:
    """
    Elije una acción de acuerdo al aprendizaje realizado previamente
    usando una política softmax
    """

    # TODO: implementar
    pass

# %% [markdown]
# Definimos el esqueleto del método learn, el cuál toma una transición y cambia el dict de los valores de Q de acuerdo a algún algoritmo.

# %%
def learn_SARSA(
        state: int,
        action: int,
        reward: int,
        next_state: int,
        next_action: int,
        q: dict
) -> None:
    """
    Realiza una actualización según el algoritmo SARSA, para una transición
    de estado dada
    Args:
        state: COMPLETAR
        action: COMPLETAR
        reward: COMPLETAR
        next_state: COMPLETAR
        next_action: COMPLETAR
    """
    alpha = hyperparameters['alpha']
    gamma = hyperparameters['gamma']
    q[(state, action)] = q[(state, action)] + alpha * (reward + gamma * q[(next_state, next_action)] - q[(state, action)])

# %%
# completar argumentos de la función para hacer una actualización Q-learning
def learn_Q_learning(
        state: int,
        action: int,
        reward: int,
        next_state: int,
        next_action: int,
        q: dict
) -> None:
    """
    Realiza una actualización según el algoritmo Q-learning, para una transición
    de estado dada
    Args: COMPLETAR
    """
    alpha = hyperparameters['alpha']
    gamma = hyperparameters['gamma']
    max_q_s_a = -1
    for a in actions:
      max_q_s_a = max(max_q_s_a, q[(next_state, a)])

    q[(state, action)] = q[(state, action)] + alpha * (reward + gamma * max_q_s_a - q[(state, action)])

# %% [markdown]
# Finalmente, definimos el método principal de iteraciones.

# %%
def run(
    learning_function: Callable,
    hyperparameters: dict,
    episodes_to_run: int,
    env: gym.Env,
    actions: range,
    q: dict,
    random_state: np.random.RandomState,
) -> Tuple[float, np.ndarray, np.ndarray]:
    """
    Corre el algoritmo de RL para el ambiente FrozenLake-v0.
    Args:
        learning_function: función de actualización de algoritmo de aprendizaje
        hyperparameters: hiperparámetros del algoritmo de aprendizaje
        episodes_to_run: cantidad de episodios a ejecutar
        env: ambiente de Gymnasium
        actions: lista de acciones posibles
        q: diccionario de valores de estado-acción
        random_state: generador de números aleatorios
    """
    # registro de la cantidad de pasos que le llevó en cada episodio
    # llegar a la salida
    timesteps_of_episode = []
    # cantidad de recompensa que recibió el agente en cada episodio
    reward_of_episode = []

    for _ in range(episodes_to_run):
        # se ejecuta una instancia del agente hasta que el mismo
        # llega a la salida o tarda más de 2000 pasos

        # reinicia el ambiente, obteniendo el estado inicial del mismo
        state, _ = env.reset()

        episode_reward = 0
        done = False
        t = 0

        # elige una acción basado en el estado actual.
        # Filtra el primer elemento de state, que es el estado en sí mismo
        action = choose_action_e_greedy(
            state, actions, q, hyperparameters, random_state)

        while not done:
            # el agente ejecuta la acción elegida y obtiene los resultados
            next_state, reward, terminated, truncated, _ = env.step(action)
            next_action = choose_action_e_greedy(
                next_state, actions, q, hyperparameters, random_state)

            episode_reward += reward
            learning_function(state, action, reward, next_state, next_action, q)

            done = terminated or truncated

            # if the algorithm does not converge, it stops after 2000 timesteps
            if not done and t < 2000:
                state = next_state
                action = next_action
            else:
                # el algoritmo no ha podido llegar a la meta antes de dar 2000 pasos
                done = True  # se establece manualmente la bandera done
                timesteps_of_episode = np.append(timesteps_of_episode, [int(t + 1)])
                reward_of_episode = np.append(
                    reward_of_episode, max(episode_reward, -100)
                )

            t += 1

    return reward_of_episode.mean(), timesteps_of_episode, reward_of_episode

# %% [markdown]
# Definidos los métodos básicos, procedemos a instanciar a nuestro agente.

# %%
# definimos sus híper-parámetros básicos
hyperparameters = {
    "alpha": 0.5,
    "gamma": 1,
    "epsilon": 0.1,
    "tau": 25,
}


episodes_to_run = 500

env = gym.make("CliffWalking-v0")
actions = range(env.action_space.n)
states = range(env.observation_space.n)


# se declara una semilla aleatoria
random_state = np.random.RandomState(42)

# %% [markdown]
# Ya instanciado, ejecutamos nuestro agente

# %%
q_sarsa = {}
for a in actions:
  for s in states:
    q_sarsa[(s,a)] = 0.0

avg_steps_per_episode_sarsa, timesteps_ep_sarsa, reward_ep_sarsa = run(
    learn_SARSA,
    hyperparameters,
    episodes_to_run,
    env,
    actions,
    q_sarsa,
    random_state
)

# %%
q = {}
for a in actions:
  for s in states:
    q[(s,a)] = 0.0

avg_steps_per_episode_q, timesteps_ep_q, reward_ep_q = run(
    learn_Q_learning,
    hyperparameters,
    episodes_to_run,
    env,
    actions,
    q,
    random_state
)

# %% [markdown]
# ### Análisis de la ejecución del agente
#
# #### Análisis de convergencia
#
# A diferencia de lo que sucede en el aprendizaje supervisado, en el aprendizaje por refuerzos el rendimiento se evalúa por una función específica que es la función de recompensa. En la práctica, la función de recompensa puede ser externa (y provista por el entorno) o bien puede ser una función creada por diseño (a modo de dirigir el agente hacia lo que por diseño se considera mejor, en nuestro ejemplo podría ser con una recompensa de $+1$ cada vez que el agente llega al estado objetivo). Esto se conoce como *reward shaping*, y hay que tener mucho cuidado con los posibles efectos secundarios de su uso.
#
# Como el objetivo de RL es maximizar la recompensa obtenida, es posible utilizar la información sobre la obtención de la recompensas en cada time-step o episodio para evaluar el rendimiento parcial del agente (esto depende mucho de la particularidad de la distribución de la recompensa para el problema tratado).

# %% [markdown]
# Para analizar la ejecución del agente, vamos a ver cómo se desempeñó el mismo en dos curvas:
#
# * Recompensa obtenida en cada episodio: nos dirá cuánta recompensa obtuvo el agente sumando cada una de recompensas individuales de cada episodio. Con esta medida podremos tener una noción de cómo se desempeñó esquivando el acantilado y llegando lo antes posible a la meta.
#
# * Pasos transcurridos en cada episodio: indicará cuántos pasos le ha llevado al agente la ejecución del episodio.
#
# Se estila suavizar ambas curvas para apreciar mejor su progresión (aunque a veces suele analizarse la curva de pasos por episodio sin suavizar).

# %% [markdown]
# Veamos recompensa por episodio (recordar que en este entorno cada paso otorga una recompensa de $-1$ excepto al caer al acantilado, donde la recompensa es de $-100$)

# %%
plot_reward_per_episode(reward_ep_sarsa)
plot_reward_per_episode(reward_ep_q)

# %% [markdown]
# Veamos pasos por episodio

# %%
plot_steps_per_episode(timesteps_ep_sarsa)
plot_steps_per_episode(timesteps_ep_q)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-efa0ef572280> in <cell line: 1>()
# ----> 1 plot_steps_per_episode(timesteps_ep_sarsa)
#       2 plot_steps_per_episode(timesteps_ep_q)
#
# <ipython-input-17-18055f40bce9> in plot_steps_per_episode(timesteps_eps)
#      39       timesteps_ep = {'value': timesteps_eps}
#      40
# ---> 41     for key, timesteps_ep in timesteps_eps.items():
#      42       legend.append(key)
#      43       # se muestra la curva de aprendizaje de los pasos por episodio
#
# AttributeError: 'numpy.ndarray' object has no attribute 'items'

# %% [markdown]
# Suavizando...

# %%
plot_steps_per_episode_smooth(timesteps_ep_sarsa)
plot_steps_per_episode_smooth(timesteps_ep_q)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-d4e002c19b1c> in <cell line: 1>()
# ----> 1 plot_steps_per_episode_smooth(timesteps_ep_sarsa)
#       2 plot_steps_per_episode_smooth(timesteps_ep_q)
#
# <ipython-input-1-18055f40bce9> in plot_steps_per_episode_smooth(timesteps_eps)
#      53     if not isinstance(timesteps_eps, dict):
#      54         timesteps_ep = {'value': timesteps_eps}
# ---> 55     for key, timesteps_ep in timesteps_eps.items():
#      56         legend.append(key)
#      57
#
# AttributeError: 'numpy.ndarray' object has no attribute 'items'

# %% [markdown]
# #### Análisis de matriz de acción-valor y política óptima
#
# Siendo que este es un ejemplo tabular y de pocos estados / acciones, es posible realizar un análisis de convergencia desde otro punto de vista: desde el valor de la función $Q(s,a)$ para la mejor acción de cada estado, al finalizar el entrenamiento del agente, (sería la acción que el agente ejecutaría en cada estado bajo una política *greedy*). Ambos nos brindarán información sobre la convergencia alcanzada por el agente.
#
# Tener en cuenta que este análisis se hace principalmente con fines educativos, para entornos más complejos el mismo puede no ser factible. En tales casos, un análisis alternativo podría consistir en hacer que el agente ejecute su política para la que fue entrenado, para hacer una evaluación a partir del comportamiento del mismo (esto último sería el *test de la política*, frente al *entrenamiento de la política* previo).

# %%
draw_value_matrix(q_sarsa)
draw_value_matrix(q)

# %%
env.close()

# %% [markdown]
# ## Actividades
#
# 1. Implementar y ejecutar el algoritmo SARSA en "The Cliff".
#
# 2. Implementar y ejecutar el algoritmo Q-Learning en "The Cliff". ¿Cómo converge con respecto a SARSA? ¿A qué se debe? Comentar.
#
# 3. Ejecutando con distintos híper-parámetros, realizar una breve descripción sobre cómo afectan a la convergencia los distintos valores de $\alpha$, $\epsilon$ y $\gamma$.
#
# 4. (Opcional) Implementar política de exploración Softmax, en donde cada acción tiene una probabilidad $$\pi(a \mid s) = \frac{e^{Q(s,a)/\tau}}{\sum_{\widetilde{a} \in A}e^{Q(s,\widetilde{a})/\tau}}$$
#
# 5. (Opcional) Implementar Dyna-Q a partir del algoritmo Q-Learning, incorporando una actualización mediante un modelo. Comentar cómo se desempeña respecto a los demás algoritmos.
#
#
# Para dejar el lab listo para su corrección, dejar link a repo de Github con un notebook ejecutando el agente en la planilla enviada en Slack.

# %% [markdown]
# # 1
#
# En el código de arriba, aquí está presentado nuevamente

# %%
def learn_SARSA(
        state: int,
        action: int,
        reward: int,
        next_state: int,
        next_action: int,
        q: dict
) -> None:
    """
    Realiza una actualización según el algoritmo SARSA, para una transición
    de estado dada
    Args:
        state: COMPLETAR
        action: COMPLETAR
        reward: COMPLETAR
        next_state: COMPLETAR
        next_action: COMPLETAR
    """
    alpha = hyperparameters['alpha']
    gamma = hyperparameters['gamma']
    q[(state, action)] = q[(state, action)] + alpha * (reward + gamma * q[(next_state, next_action)] - q[(state, action)])

# %% [markdown]
# # 2
#
# En el código de arriba, aquí está presentado nuevamente

# %%
def learn_Q_learning(
        state: int,
        action: int,
        reward: int,
        next_state: int,
        next_action: int,
        q: dict
) -> None:
    """
    Realiza una actualización según el algoritmo Q-learning, para una transición
    de estado dada
    Args: COMPLETAR
    """
    alpha = hyperparameters['alpha']
    gamma = hyperparameters['gamma']
    max_q_s_a = -1
    for a in actions:
      max_q_s_a = max(max_q_s_a, q[(next_state, a)])

    q[(state, action)] = q[(state, action)] + alpha * (reward + gamma * max_q_s_a - q[(state, action)])

# %% [markdown]
# ## 3.

# %% [markdown]
# ### SARSA
#
# Probamos diferentes valores para los hiperparámetros. Luego analizamos los gráficos para sacar conclusiones.
#
# Comenzamos modificando $\alpha$.

# %%
hyperparameters = {
    "alpha": 0.5,
    "gamma": 1,
    "epsilon": 0.1,
    "tau": 25,
}

q = {}
for alpha in [0.1, 0.25, 0.5, 0.75, 1]:
  q[alpha] = {}

for alpha in [0.1, 0.25, 0.5, 0.75, 1]:
  for a in actions:
    for s in states:
      q[alpha][(s,a)] = 0.0

avg_steps_per_episode = {}
timesteps_ep = {}
reward_ep = {}
for alpha in [0.1, 0.25, 0.5, 0.75, 1]:
  hyperparameters['alpha'] = alpha
  avg_steps_per_episode[alpha], timesteps_ep[alpha], reward_ep[alpha] = run(
      learn_SARSA,
      hyperparameters,
      episodes_to_run,
      env,
      actions,
      q[alpha],
      random_state
  )

# %%
plot_reward_per_episode(reward_ep)

# %% [markdown]
# Mientras más alto el valor de $\alpha$, más ráido se alcanza la convergencia en la recompensa. Esto se debe a que alfa representa la tasa de aprendizaje en el algoritmo Q-learning. Una tasa de aprendizaje más alta significa que el agente dará más importancia a las nuevas experiencias (fomenta la exploración), lo que potencialmente conducirá a una convergencia más rápida, pero con el riesgo de sobrepasar los valores óptimos. Por el contrario, una tasa de aprendizaje más baja hace que el agente sea más conservador, dependa más del conocimiento existente y potencialmente tarde más en converger, pero con más estabilidad. Eso se ve claramente en el gráfico. A su vez, aunque la convergencia se alcanza siempre, no se alcanza para los mismos valores. Claramente valores intermedios de alfa (0.25 y 0.5) están asociados a un recompensa por episodio mayor, por lo que el óptimo yace allí.

# %%
plot_steps_per_episode(timesteps_ep)

# %%
plot_steps_per_episode_smooth(timesteps_ep)

# %% [markdown]
# En cuanto a los pasos acumulados por episodio, mientras mayor el alfa, menos pasos acumulados, lo cual se vincula a lo dicho anteriormente.Ahora vemos las matrices de acción-valor.

# %%
for alpha in [0.1, 0.25, 0.5, 0.75, 1]:
  print(alpha)
  draw_value_matrix(q[alpha])
# Out:
# 0.1
# 0.25
# 0.5
# 0.75
# 1

# %% [markdown]
# Para valores de entre 0 y 0.5 no se observan grandes diferencias. Las mismas surgen desde $\alpha = 0.75$ en adelante. A partir de allí claramente el nivel de aprendizaje es tan alto que casi siempre se toma una decisión óptima. Cuando alfa es igual esto es muy claro. La convergencua se alcanza rápidamente en este último caso.
#
# Ahora pasamos a modificar los valores de gamma ($\gamma$).

# %%
hyperparameters = {
    "alpha": 0.5,
    "gamma": 1,
    "epsilon": 0.1,
    "tau": 25,
}

q = {}
for gamma in [0.1, 0.25, 0.5, 0.75, 1]:
  q[gamma] = {}

for gamma in [0.1, 0.25, 0.5, 0.75, 1]:
  for a in actions:
    for s in states:
      q[gamma][(s,a)] = 0.0

avg_steps_per_episode = {}
timesteps_ep = {}
reward_ep = {}
for gamma in [0.1, 0.25, 0.5, 0.75, 1]:
  hyperparameters['gamma'] = gamma
  avg_steps_per_episode[gamma], timesteps_ep[gamma], reward_ep[gamma] = run(
      learn_SARSA,
      hyperparameters,
      episodes_to_run,
      env,
      actions,
      q[gamma],
      random_state
  )

# %%
plot_reward_per_episode(reward_ep)

# %% [markdown]
# Una diferencia con el caso anterior (alfa), es que ahora la convergencia es muy diferente según el valor de gamma. Esto se debe a que gamma determina la importancia de las recompensas futuras en relación con las recompensas inmediatas. Un factor de descuento más alto valora más las recompensas futuras, lo que anima al agente a considerar las consecuencias a largo plazo. Un gammma más elevado conduce a un agente con más visión de futuro, entonces es probable que el agente prefiera acciones que puedan generar recompensas inmediatas más pequeñas pero que conduzcan a recompensas acumulativas mayores a futuro.
#
# Esto se verifica al comparar la línea azul (gamma=0.1) con la violeta (gamma=1). Para los primeros episodios la recompensa acumulada es mayor para el azul, pero a medida que aumenta el número de episodios la tendencia se revierte y terminan en extremos opuestos.

# %%
plot_steps_per_episode(timesteps_ep)

# %%
plot_steps_per_episode_smooth(timesteps_ep)

# %% [markdown]
# En línea con lo dicho en el párrado anterior, la ineficiencia de un gamma demasiado bajo lleva a que el número de timesteps sea exageradamente alto. La adecuación del valor de gamma es específico al problema. Puede que con aglún otro problema la valoración por el futuro no sea relevante.

# %%
for gamma in [0.1, 0.25, 0.5, 0.75, 1]:
  print(gamma)
  draw_value_matrix(q[gamma])
# Out:
# 0.1
# 0.25
# 0.5
# 0.75
# 1

# %% [markdown]
# La matriz cambia abruptamente (en sentido positivo) para valores altos de gamma, que le dan mayor capacidad al algoritmo para considerar consecuencias a futuro (como puede ser una eventual caída al precipicio).
#
# Finalmente, modificamos los valores de epsilon.

# %%
hyperparameters = {
    "alpha": 0.5,
    "gamma": 1,
    "epsilon": 0.1,
    "tau": 25,
}

q = {}
for epsilon in [0.1, 0.25, 0.5, 0.75, 1]:
  q[epsilon] = {}

for epsilon in [0.1, 0.25, 0.5, 0.75, 1]:
  for a in actions:
    for s in states:
      q[epsilon][(s,a)] = 0.0

avg_steps_per_episode = {}
timesteps_ep = {}
reward_ep = {}
for epsilon in [0.1, 0.25, 0.5, 0.75, 1]:
  hyperparameters['epsilon'] = epsilon
  avg_steps_per_episode[epsilon], timesteps_ep[epsilon], reward_ep[epsilon] = run(
      learn_SARSA,
      hyperparameters,
      episodes_to_run,
      env,
      actions,
      q[epsilon],
      random_state
  )

# %%
plot_reward_per_episode(reward_ep)

# %% [markdown]
# A medida que aumenta epsilon disminuye la recompensa por episodio. Esto es consecuencia de que epsilon representa el trade-off entre exploración y explotación. Un epsilon superior implica que es más probable que el agente explore. Elegirá acciones aleatorias con más frecuencia, lo que le permitirá descubrir nuevos estados y estrategias potencialmente mejores. El problema es que el agente puede dedicar demasiado tiempo a explorar y no suficiente a explotar buenas estrategias conocidas, lo que podría ralentizar la convergencia hacia una política óptima, o que directamente no explote y quede en la nada.
#
# De nuevo, hay que econtrar un óptimo. Un valor como 0.25 implica una convergencia más rápida.

# %%
plot_steps_per_episode(timesteps_ep)

# %%
plot_steps_per_episode_smooth(timesteps_ep)

# %% [markdown]
# Vinculado a lo anterior, un epsilon demasiado alto no otorga buenos resultados, ya que prácticamente no hay explotación.

# %%
for epsilon in [0.1, 0.25, 0.5, 0.75, 1]:
  print(epsilon)
  draw_value_matrix(q[epsilon])
# Out:
# 0.1
# 0.25
# 0.5
# 0.75
# 1

# %% [markdown]
# Diferentes valores de epsilon derivan en valores para las celdas de matriz distintos, que empeoran a notoriamente para un epsilon=1.

# %% [markdown]
# ### Q-Learning
#
# Ahora pasamos a repetir el proceso anterior, esta vez con Q-learning.
#
# Comenzamos con $\alpha$.

# %%
hyperparameters = {
    "alpha": 0.5,
    "gamma": 1,
    "epsilon": 0.1,
    "tau": 25,
}

q = {}
for alpha in [0.1, 0.25, 0.5, 0.75, 1]:
  q[alpha] = {}

for alpha in [0.1, 0.25, 0.5, 0.75, 1]:
  for a in actions:
    for s in states:
      q[alpha][(s,a)] = 0.0

avg_steps_per_episode = {}
timesteps_ep = {}
reward_ep = {}
for alpha in [0.1, 0.25, 0.5, 0.75, 1]:
  hyperparameters['alpha'] = alpha
  avg_steps_per_episode[alpha], timesteps_ep[alpha], reward_ep[alpha] = run(
      learn_Q_learning,
      hyperparameters,
      episodes_to_run,
      env,
      actions,
      q[alpha],
      random_state
  )

# %%
plot_reward_per_episode(reward_ep)

# %% [markdown]
# La convergencia se da de forma diferente a SARSA. Para valores mayores a 0.5 la recompensa por episodio se comporta con un overshooting inicial, para luego converger de forma similar al resto de los valores de alfa.

# %%
plot_steps_per_episode(timesteps_ep)

# %%
plot_steps_per_episode_smooth(timesteps_ep)

# %% [markdown]
# Ocurre lo mismo con los timesteps, aunque la convergencia se alcanza siempre, la forma en la que se llega no es la misma.

# %%
for alpha in [0.1, 0.25, 0.5, 0.75, 1]:
  print(alpha)
  draw_value_matrix(q[alpha])
# Out:
# 0.1
# 0.25
# 0.5
# 0.75
# 1

# %% [markdown]
# No se verifican diferencias entre las matrices al variar el valor de alfa.
#
# Pasamos a analizar cambios en gamma.

# %%
hyperparameters = {
    "alpha": 0.5,
    "gamma": 1,
    "epsilon": 0.1,
    "tau": 25,
}

q = {}
for gamma in [0.1, 0.25, 0.5, 0.75, 1]:
  q[gamma] = {}

for gamma in [0.1, 0.25, 0.5, 0.75, 1]:
  for a in actions:
    for s in states:
      q[gamma][(s,a)] = 0.0

avg_steps_per_episode = {}
timesteps_ep = {}
reward_ep = {}
for gamma in [0.1, 0.25, 0.5, 0.75, 1]:
  hyperparameters['gamma'] = gamma
  avg_steps_per_episode[gamma], timesteps_ep[gamma], reward_ep[gamma] = run(
      learn_Q_learning,
      hyperparameters,
      episodes_to_run,
      env,
      actions,
      q[gamma],
      random_state
  )

# %%
plot_reward_per_episode(reward_ep)

# %% [markdown]
# Se observa mucha varianza, pero claramente valores extremos de gamma implican una convergencia hacia vaolores muy bajos de recompensa. El óptimo se encuentra para valores de gamma intermedios (0.5 y 0.75).

# %%
plot_steps_per_episode(timesteps_ep)

# %%
plot_steps_per_episode_smooth(timesteps_ep)

# %%
for gamma in [0.1, 0.25, 0.5, 0.75, 1]:
  print(gamma)
  draw_value_matrix(q[gamma])
# Out:
# 0.1
# 0.25
# 0.5
# 0.75
# 1

# %% [markdown]
# Finalmente, epsilon.

# %%
hyperparameters = {
    "alpha": 0.5,
    "gamma": 1,
    "epsilon": 0.1,
    "tau": 25,
}

q = {}
for epsilon in [0.1, 0.25, 0.5, 0.75, 1]:
  q[epsilon] = {}

for epsilon in [0.1, 0.25, 0.5, 0.75, 1]:
  for a in actions:
    for s in states:
      q[epsilon][(s,a)] = 0.0

avg_steps_per_episode = {}
timesteps_ep = {}
reward_ep = {}
for epsilon in [0.1, 0.25, 0.5, 0.75, 1]:
  hyperparameters['epsilon'] = epsilon
  avg_steps_per_episode[epsilon], timesteps_ep[epsilon], reward_ep[epsilon] = run(
      learn_Q_learning,
      hyperparameters,
      episodes_to_run,
      env,
      actions,
      q[epsilon],
      random_state
  )

# %%
plot_reward_per_episode(reward_ep)

# %% [markdown]
# Claramente el algoritmo es muy sensible a epsilon. El óptimo parece hallarse en este caso alrededor de 0.1. No hace falta demasiado exploración.

# %%
plot_steps_per_episode(timesteps_ep)

# %%
plot_steps_per_episode_smooth(timesteps_ep)

# %% [markdown]
# Al ver los timesteps, es muy marcado que pequeñas variaciones de epsilon impactan notoriamente en esta variable. Mientras mayor es epsilon, mayores los pasos acumulados.

# %%
for epsilon in [0.1, 0.25, 0.5, 0.75, 1]:
  print(epsilon)
  draw_value_matrix(q[epsilon])
# Out:
# 0.1
# 0.25
# 0.5
# 0.75
# 1
